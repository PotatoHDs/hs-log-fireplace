# %%
import time
from pathlib import Path

hs_path = Path('/') / 'Applications' / 'Hearthstone' / 'Logs' / 'Power.log'
file = open(hs_path, "r")
while True:
    line = file.readline()
    if line:
        print(line)
    else:
        time.sleep(0.2)
# Out:
# D 23:34:15.2332650 GameState.OnEntityChoices() - id=1 playerId=1 queued
#
# D 23:34:15.3072900 GameState.OnEntityChoices() - id=2 playerId=2 queued
#
# D 23:34:15.3391490 GameState.OnEntitiesChosen() - id=2 playerId=2 queued
#
# D 23:34:16.5027710 GameState.DebugPrintPowerList() - Count=103
#
# D 23:34:16.5027710 GameState.DebugPrintPower() - CREATE_GAME
#
# D 23:34:16.5027710 GameState.DebugPrintPower() -     GameEntity EntityID=1
#
# D 23:34:16.5027710 GameState.DebugPrintPower() -         tag=CARDTYPE value=GAME
#
# D 23:34:16.5027710 GameState.DebugPrintPower() -         tag=ZONE value=PLAY
#
# D 23:34:16.5027710 GameState.DebugPrintPower() -         tag=ENTITY_ID value=1
#
# D 23:34:16.5027710 GameState.DebugPrintPower() -         tag=937 value=268
#
# D 23:34:16.5027710 GameState.DebugPrintPower() -         tag=SPAWN_TIME_COUNT value=1
#
# D 23:34:16.5027710 GameState.DebugPrintPower() -     Player EntityID=2 PlayerID=1 GameAccountId=[hi=144115198130930503 lo=62733022]
#
# ...
